# %% [markdown]
# # Importing libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
df=pd.read_csv(r"D:\Data Analytics Projects\London Housing data\file.csv")
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# ## Aanalysing the data

# %%
df.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
df.shape
# Out:
# (13549, 6)

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %% [markdown]
# #### Finding Null and NaN values

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
df.isna().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %% [markdown]
# ### Finding null values with the help of Seaborn

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull())
plt.title(" Finding null values with heatmap", fontsize=14,weight="bold")
plt.xlabel("Cols Header")
plt.ylabel("Rows")
plt.show()

# %%
df.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## Checking unique values for all the cols
# #### i.e checking for not availabel values

# %%
df['area'].unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
df['code'].unique()
# Out:
# array(['E09000001', 'E09000002', 'E09000003', 'E09000004', 'E09000005',
#        'E09000006', 'E09000007', 'E09000008', 'E09000009', 'E09000010',
#        'E09000030', 'E09000011', 'E09000012', 'E12000008', 'E09000013',
#        'E09000014', 'E09000015', 'E09000016', 'E09000017', 'E09000018',
#        'E09000019', 'E09000020', 'E09000021', 'E09000022', 'E09000023',
#        'E09000024', 'E09000025', 'E09000026', 'E09000027', 'E09000028',
#        'E09000029', 'E09000031', 'E09000032', 'E09000033', 'E13000001',
#        'E13000002', 'E12000001', 'E12000002', 'E12000003', 'E12000004',
#        'E12000005', 'E12000006', 'E12000007', 'E12000009', 'E92000001'],
#       dtype=object)

# %%
df['no_of_crimes'].unique()
# Out:
# array([      nan, 0.000e+00, 7.000e+00, ..., 6.843e+03, 7.461e+03,
#        6.405e+03])

# %%
df['houses_sold'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13544    False
# 13545    False
# 13546    False
# 13547     True
# 13548     True
# Name: houses_sold, Length: 13549, dtype: bool

# %%
pd.isnull(df.loc[13547, 'houses_sold'])
# Out:
# True

# %%
df.loc[13547, 'houses_sold']
# Out:
# nan

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
df['houses_sold'].isnull().sum()
# Out:
# 94

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %% [markdown]
# # Casting the object

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %% [markdown]
# ## Converting the datatype of date from object to date

# %% [markdown]
# ## Q1) Covert the object of date to date from object

# %%
df.head(25)
# Out:
#          date            area  average_price       code  houses_sold  \
# 0    1/1/1995  city of london          91449  E09000001         17.0
# 1    2/1/1995  city of london          82203  E09000001          7.0
# 2    3/1/1995  city of london          79121  E09000001         14.0
# 3    4/1/1995  city of london          77101  E09000001          7.0
# 4    5/1/1995  city of london          84409  E09000001         10.0
# 5    6/1/1995  city of london          94901  E09000001         17.0
# 6    7/1/1995  city of london         110128  E09000001         13.0
# 7    8/1/1995  city of london         112329  E09000001         14.0
# 8    9/1/1995  city of london         104473  E09000001         17.0
# 9   10/1/1995  city of london         108038  E09000001         14.0
# 10  11/1/1995  city of london         117636  E09000001         11.0
# 11  12/1/1995  city of london         127232  E09000001         18.0
# 12   1/1/1996  city of london         108999  E09000001         17.0
# ...

# %%
df['date'] = pd.to_datetime(df['date']) ## with this pandas decides automatically what to use

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df[df['area'] == 'england']
# Out:
#             date     area  average_price       code  houses_sold  no_of_crimes
# 13248 1995-01-01  england          53203  E92000001      47639.0           NaN
# 13249 1995-02-01  england          53096  E92000001      47880.0           NaN
# 13250 1995-03-01  england          53201  E92000001      67025.0           NaN
# 13251 1995-04-01  england          53591  E92000001      56925.0           NaN
# 13252 1995-05-01  england          53678  E92000001      64192.0           NaN
# ...          ...      ...            ...        ...          ...           ...
# 13544 2019-09-01  england         249942  E92000001      64605.0           NaN
# 13545 2019-10-01  england         249376  E92000001      68677.0           NaN
# 13546 2019-11-01  england         248515  E92000001      67814.0           NaN
# 13547 2019-12-01  england         250410  E92000001          NaN           NaN
# 13548 2020-01-01  england         247355  E92000001          NaN           NaN
#
# [301 rows x 6 columns]

# %% [markdown]
# ## Q2) Add a column year in the dataFrame , Which only contain year

# %%
df['year'] = df['date'].dt.year

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %% [markdown]
# ## Q3) Add a column month in the dataFrame , Which only contain month

# %%
df['month'] = df['date'].dt.month

# %%
### Add it to second place
df.insert(1, 'month', df.pop('month'))

# %%
df
# Out:
#             date  month            area  average_price       code  \
# 0     1995-01-01      1  city of london          91449  E09000001
# 1     1995-02-01      2  city of london          82203  E09000001
# 2     1995-03-01      3  city of london          79121  E09000001
# 3     1995-04-01      4  city of london          77101  E09000001
# 4     1995-05-01      5  city of london          84409  E09000001
# ...          ...    ...             ...            ...        ...
# 13544 2019-09-01      9         england         249942  E92000001
# 13545 2019-10-01     10         england         249376  E92000001
# 13546 2019-11-01     11         england         248515  E92000001
# 13547 2019-12-01     12         england         250410  E92000001
# 13548 2020-01-01      1         england         247355  E92000001
#
#        houses_sold  no_of_crimes  year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...

# %% [markdown]
# ## Q4) Remove column month and year

# %%
df.drop(['month','year'],axis=1,inplace=True)

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# ## Q5) Show all the records where number of crimes is zero. And how many such records are there

# %%
df[df['no_of_crimes']==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(df['no_of_crimes']==0)
# Out:
# 13549

# %% [markdown]
# ## Q6) what is minimum and maximum average price per year in england

# %%
df['year'] = df['date'].dt.year

# %%
df1=df[df.area=='england']
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
df1.groupby('year').average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
df.groupby('year').average_price.max()
# Out:
# year
# 1995     200722
# 1996     223197
# 1997     265112
# 1998     277600
# 1999     354241
# 2000     397353
# 2001     451028
# 2002     497538
# 2003     488704
# 2004     559286
# 2005     555847
# 2006     644541
# 2007     830950
# 2008     832753
# 2009     782459
# 2010     884674
# 2011     959520
# 2012    1077366
# 2013    1217729
# 2014    1365050
# 2015    1353679
# 2016    1357231
# 2017    1412255
# 2018    1463378
# 2019    1294113
# 2020    1178166
# Name: average_price, dtype: int64

# %%
df.groupby('year').average_price.mean()
# Out:
# year
# 1995     75880.235185
# 1996     78875.274908
# 1997     89618.350000
# 1998    101747.073801
# 1999    114256.172222
# 2000    139979.442593
# 2001    156932.355556
# 2002    182190.731481
# 2003    205099.553704
# 2004    224604.720370
# 2005    233314.512963
# 2006    249303.109259
# 2007    285944.279630
# 2008    287478.972222
# 2009    259296.896296
# 2010    287559.164815
# 2011    294819.138889
# 2012    309409.501852
# 2013    334589.564815
# 2014    388208.392593
# 2015    421356.100000
# 2016    454884.461111
# 2017    469978.938889
# 2018    467240.674074
# 2019    460056.659259
# 2020    463329.977778
# Name: average_price, dtype: float64

# %% [markdown]
# ## Q7) What is the maximum and minimum crimes recorded per aarea

# %%
df.groupby('area').no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
df.groupby('area').no_of_crimes.min().sort_values(ascending=True)
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# ealing                    1871.0
# islington                 1871.0
# croydon                   2031.0
# ...

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# year                0
# dtype: int64

# %% [markdown]
# ## Q8) Show the total count of records of each area , Where avarage price is less than 1,00,000

# %%
df[df.average_price <100000]
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13330 2001-11-01         england          95083  E92000001     109149.0
# 13331 2001-12-01         england          95992  E92000001      93329.0
# 13332 2002-01-01         england          96215  E92000001      71678.0
# 13333 2002-02-01         england          96676  E92000001      77131.0
# 13334 2002-03-01         england          98962  E92000001     102828.0
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
df[df.average_price <100000].area.value_counts()
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...

# %% [markdown]
# # Loading dataset into mySql server

# %%
from sqlalchemy import create_engine
import pymysql
# MySQL connection details
username = 'root'
password = '1234'
host = 'localhost'  # or your MySQL server's IP
port = '3306'       # Default MySQL port
database = 'london_housing'  # Replace with your database name

# Create SQLAlchemy engine
connection_string = f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}'
engine = create_engine(connection_string)

# Write DataFrame to MySQL
df.to_sql(
    name='house_data',  # Replace with the desired table name
    con=engine,
    if_exists='replace',     # Replace the table if it already exists
    index=False              # Avoid writing the DataFrame index as a column
)
# Close the connection
engine.dispose()

# %% [markdown]
# # Running Queries in mysql

# %% [markdown]
# # Q8) -- Calculate total no. of houses sold per area

# %%
from sqlalchemy import create_engine
import pandas as pd

# Create an SQLAlchemy engine for MySQL
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/london_housing")

query = """
SELECT area, SUM(houses_sold) AS total_houses_sold
FROM house_data
GROUP BY area;
"""
df = pd.read_sql(query, engine)

# Close the engine after use (optional in most cases)
engine.dispose()
# Plotting the data (Bar Plot)
plt.figure(figsize=(12, 6))
sns.barplot(x='area', y='total_houses_sold', data=df)
plt.title('Total Houses Sold by Area')
plt.xlabel('Area')
plt.ylabel('Total Houses Sold')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # Q9) Find the average house price by area

# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create an SQLAlchemy engine for MySQL
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/london_housing")

# Corrected query string
query = """
select area, avg(average_price) as avg_house_price
from house_data
group by area;
"""

df = pd.read_sql(query, engine)

# Close the engine after use (optional in most cases)
engine.dispose()

# Plotting the data
plt.figure(figsize=(14, 7))
sns.set(style="whitegrid")

# Bar plot showing average house price by area
sns.barplot(x='area', y='avg_house_price', data=df, palette="coolwarm", hue='area')
plt.title("Average house price by area", fontsize=14, weight="bold")
plt.xlabel("Area")
plt.ylabel("Average House Price")
plt.xticks(rotation=45, ha='right', fontsize=8)

# Adding data labels on top of bars for clarity
for index, row in df.iterrows():
    plt.text(row.name, row.avg_house_price, round(row.avg_house_price, 2), color='black', ha="center", va="bottom", fontsize=12)

plt.grid(True, axis='y', linestyle='--', alpha=0.7)  # Adding grid for better readability

plt.tight_layout()  # Adjust the layout to prevent overlap
plt.show()

# %% [markdown]
# ## Q10) Find Areas with the Highest Crime Rates

# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create an SQLAlchemy engine for MySQL
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/london_housing")

# SQL query to fetch the data
query = """
SELECT area, year, AVG(average_price) AS avg_house_price
FROM house_data
GROUP BY year, area
ORDER BY year;
"""

# Read data into a pandas DataFrame
df = pd.read_sql(query, engine)

# Close the engine after use
engine.dispose()

# Plotting the data
plt.figure(figsize=(30,30))
sns.set(style="whitegrid")

# Line plot with 'year' on the x-axis, 'avg_house_price' on the y-axis, and hue for 'area'
sns.lineplot(data=df, x='year', y='avg_house_price', hue='area', marker="o", palette="tab10")

# Adding plot details
plt.title("Average House Price by Area Over Years", fontsize=16, weight="bold")
plt.xlabel("Year", fontsize=12)
plt.ylabel("Average House Price", fontsize=12)
plt.legend(title="Area", loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)

# Adjust layout to fit everything nicely
plt.tight_layout()

# Show the plot
plt.show()

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/london_housing")

# Query to fetch data
query = """
select area, sum(no_of_crimes) as total_crimes
from house_data
group by area
order by total_crimes desc
limit 10;
"""

# Execute the query and load data into a DataFrame
df = pd.read_sql(query, engine)

# Close the engine after use (optional in most cases)
engine.dispose()

# Truncate long area names for readability
df['area'] = df['area'].str[:15] + "..." if df['area'].str.len().max() > 15 else df['area']

# Plotting the data
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")

# Horizontal bar plot for the top 10 areas with the most crimes
sns.barplot(x='total_crimes', y='area', data=df, hue='area',palette="Reds_r")
plt.title("Top 10 Areas with the Most Crimes", fontsize=14, weight="bold")
plt.xlabel("Total Crimes", fontsize=12)
plt.ylabel("Area", fontsize=12)

# Adding data labels on bars
for index, row in df.iterrows():
    plt.text(row.total_crimes, index, row.total_crimes, color='black', va="center", fontsize=10)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# ## Q11)
# ### What are the yearly trends in average house prices across different areas of London?
# ### Which area has shown the highest increase in average house prices over the last decade?
# ### What are the areas with the highest increase in the average price

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/london_housing")

query_trends = """
SELECT year, area, AVG(average_price) AS avg_house_price
FROM house_data
GROUP BY year, area
ORDER BY year, area;
"""

# Query for area with highest increase in average house prices
query_highest_increase = """
WITH price_trends AS (
    SELECT area, year, AVG(average_price) AS avg_house_price
    FROM house_data
    GROUP BY year, area
)
SELECT area, MAX(avg_house_price) - MIN(avg_house_price) AS price_increase
FROM price_trends
GROUP BY area
ORDER BY price_increase DESC
LIMIT 10;
"""

# Execute the queries
df_trends = pd.read_sql(query_trends, engine)
df_highest_increase = pd.read_sql(query_highest_increase, engine)
engine.dispose()

# plotting yearly trend
plt.figure(figsize=(10,8))
sns.lineplot(data=df_trends,x='year',y='avg_house_price', hue='area', marker='o')
plt.title("Yearly Trends in Average House price", fontsize=14,weight="bold")
plt.xlabel("Year",fontsize=10)
plt.ylabel("Average house Price",fontsize=10)
plt.xticks(rotation=90)
plt.legend(loc="upper left", title="Area", bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

print("Area with the highest increase in average house prices:", df_highest_increase["area"][0])
# Out:
# Area with the highest increase in average house prices: kensington and chelsea

# %% [markdown]
# ### Area with highest increase in House Price

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import pandas as pd

# SQL query for the highest increase in average house prices
query_highest_increase = """
WITH price_trends AS (
    SELECT area, year, AVG(average_price) AS avg_house_price
    FROM house_data
    GROUP BY year, area
)
SELECT area, MAX(avg_house_price) - MIN(avg_house_price) AS price_increase
FROM price_trends
GROUP BY area
ORDER BY price_increase DESC
LIMIT 10;
"""

# Create SQLAlchemy engine and execute query
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/london_housing")
df_highest_increase = pd.read_sql(query_highest_increase, engine)
engine.dispose()

# Plotting the highest increase in house prices
plt.figure(figsize=(12, 8))
sns.barplot(
    x="price_increase", 
    y="area", 
    data=df_highest_increase, 
    palette="viridis",
    hue="price_increase"
)

plt.title("Top 10 Areas with Highest Increase in House Prices", fontsize=16, weight="bold")
plt.xlabel("Price Increase", fontsize=12)
plt.ylabel("Area", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q12)
# ## How does the crime rate in an area correlate with house prices?
# ## Do areas with higher crime rates see a slower increase in house prices compared to areas with lower crime rates?
# ## Is there a relationship between the number of crimes and the number of houses sold in a specific area?

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/london_housing")
# Load data for correlation analysis
query_crime_prices = """
WITH crime_house_data AS (
    SELECT 
        area, 
        AVG(average_price) AS avg_house_price, 
        SUM(no_of_crimes) AS total_crimes
    FROM house_data
    GROUP BY area
)
SELECT 
    area, 
    avg_house_price, 
    total_crimes
FROM crime_house_data;
"""

df_crime_prices = pd.read_sql(query_crime_prices, engine)
engine.dispose()

# Correlation Analysis
correlation = df_crime_prices['total_crimes'].corr(df_crime_prices['avg_house_price'])
print(f"Correlation between crime rate and house prices: {correlation:.2f}")

# Scatter plot for crime vs house prices
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_crime_prices, x='total_crimes', y='avg_house_price', hue='area', palette='viridis', s=100)
plt.title("Correlation Between Crime Rates and House Prices", fontsize=14, weight="bold")
plt.xlabel("Total Crimes", fontsize=12)
plt.ylabel("Average House Price", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Correlation between crime rate and house prices: 0.18
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_27684\1169145375.py:33: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
